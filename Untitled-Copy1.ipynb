# %% [markdown]
# # Información

# %% [markdown]
# 1. Descricpción del problema
# 1. Data cleaning y formatting
# 1. EDA
# 3. Feature selecction y engenieering
# 4. Comparación de modelos
# 5. Hyperparameter tunning sobre el mejor modelo
# 6. Evaluacion
# 7. Interpretación
# 8. Conclusión

# %% [markdown]
# # 0. IMPORTACIONES Y SETEOS

# %% [markdown]
# ## Imports

# %%
# Pandas and numpy para manipulación
import pandas as pd
import numpy as np

# Se importa para el tamaño de la imagen
from IPython.core.pylabtools import figsize

# Seaborn para las visualizaciones
import seaborn as sns
sns.set(font_scale = 2)

# Herramientas de modelado
from sklearn.model_selection import train_test_split

# Funciones de DS
import DSImplementation as dsimp

#missing values 
import missingno as msno

# %% [markdown]
# ## Seteos

# %%
# No warnings about setting value on copy of slice
pd.options.mode.chained_assignment = None

# Display up to 60 columns of a dataframe
pd.set_option('display.max_columns', 60)

# Matplotlib visualization
import matplotlib.pyplot as plt
# %matplotlib inline

# Set default font size
plt.rcParams['font.size'] = 24

# %% [markdown]
# # 1. DESCRIPCIÓN DEL PROBLEMA

# %% [markdown]
# # 2. DATA CLEANING Y FORMATING

# %% [markdown]
# * El data set ya viene separado entre train y test, pero para mejor la practica se las une en un solo lugar.

# %% [markdown]
# ## Carga del dataset a trabajar

# %%
# Se carga el dataset
data_train = pd.read_csv("data/train.csv")
data_test = pd.read_csv("data/test.csv")

# Se prefiere unir las tablas para trabajarlas
data = pd.concat([data_train, data_test])
data.head(5)
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2   2         20       756  2549     9     7         19
# 1        136        3   6        905      1988  2631    17     3          7
# 2        145        5   6       1263      1716  2603    11     2          9
# 3        131        6   9       1216      1786  2769    16     8         11
# 4        141        2  14       1208      1212  1411     8     2         15
#
# ...

# %%
# Se observa que al concatenar las tablas hay una columna de mas "ID" de test
columns_compare = list(map(set, [data_test.columns, data_train.columns, data.columns]))
for i,name in enumerate(columns_compare):
    column_diff = columns_compare[i] - columns_compare[i-1]
column_diff
print (data_test.shape, data_train.shape, data.shape, column_diff)
# Out:
# (1000, 21) (2000, 21) (3000, 22) {'id'}

# %% [markdown]
# ## Tipo de datos, valores faltantes y valores nulos

# %% [markdown]
# ### Valores nulos y tipo de datos

# %% [markdown]
# * Se observa el tipo de dato de las columnas y no poseen valores nulos.
# * Se observa que "price range" y "id" tienen valores faltantes, lo cual tiene sentido dado que son de datasets diferentes
# * No se observan columnas objects y mantienen el tipo de dato

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3000 entries, 0 to 999
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  3000 non-null   int64
#  1   blue           3000 non-null   int64
#  2   clock_speed    3000 non-null   float64
#  3   dual_sim       3000 non-null   int64
#  4   fc             3000 non-null   int64
#  5   four_g         3000 non-null   int64
#  6   int_memory     3000 non-null   int64
#  7   m_dep          3000 non-null   float64
#  8   mobile_wt      3000 non-null   int64
#  9   n_cores        3000 non-null   int64
#  10  pc             3000 non-null   int64
#  11  px_height      3000 non-null   int64
#  12  px_width       3000 non-null   int64
#  13  ram            3000 non-null   int64
#  14  sc_h           3000 non-null   int64
#  15  sc_w           3000 non-null   int64
#  16  talk_time      3000 non-null   int64
#  17  three_g        3000 non-null   int64
# ...

# %% [markdown]
#  ### Valores faltantes

# %% [markdown]
# Observamos los valores faltantes. Podes sacar la columna ID que no nos sirve, mientras que price_range es nuestra variable de destino, asi que se trabajará despues

# %%
dsimp.missing_values_table(data)
# Out:
# Your selected dataframe has 22 columns.
# There are 2 columns that have missing values.
#              Missing Values  % of Total Values
# id                     2000               66.7
# price_range            1000               33.3

# %%
msno.matrix(data)
# Out:
# <AxesSubplot:>

# %%
data = data.drop(columns=['id']);

# %% [markdown]
# ### Completar valores faltantes de price range

# %% [markdown]
# Debido a que solo falta el 33.3%, y consideramos que es menor al 50% podemos completar los valores faltantes

# %%
data_train
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %% [markdown]
# ### Analisis de clases para evaluar el balance

# %% [markdown]
# Se observa que las clases estan balanceadas.

# %%
data.price_range.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # 3. EDA
